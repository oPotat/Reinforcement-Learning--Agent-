# %%
import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym

# %%
# Initialise the environment
env = gym.make("LunarLander-v3", render_mode="human")  # Not used in any of the labs.
